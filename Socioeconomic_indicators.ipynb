# %%
import pandas as pd

file_path = "/content/Census_Data_-_Selected_socioeconomic_indicators_in_Chicago,_2008_–_2012_20250920.csv"

try:
    df = pd.read_csv(file_path)
    display(df.head())
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
    print("Please make sure the file is uploaded or the correct path is provided.")
# Out:
#    Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# ...

# %%
#How many rows are in the dataset?
num_rows = df.shape[0]
print(f"The dataset has {num_rows} rows.")
# Out:
# The dataset has 78 rows.

# %%
hardship_above_50 = df[df['HARDSHIP INDEX'] > 50.0]
num_community_areas = hardship_above_50.shape[0]
print(f"Number of community areas with hardship index greater than 50.0: {num_community_areas}")
# Out:
# Number of community areas with hardship index greater than 50.0: 38

# %%
max_hardship_index = df['HARDSHIP INDEX'].max()
print(f"The maximum hardship index in the dataset is: {max_hardship_index}")

# %%
max_hardship_index = df['HARDSHIP INDEX'].max()
print(f"The maximum hardship index in the dataset is: {max_hardship_index}")
# Out:
# The maximum hardship index in the dataset is: 98.0

# %%
highest_hardship_area = df[df['HARDSHIP INDEX'] == df['HARDSHIP INDEX'].max()]
display(highest_hardship_area[['COMMUNITY AREA NAME', 'HARDSHIP INDEX']])
# Out:
#    COMMUNITY AREA NAME  HARDSHIP INDEX
# 53           Riverdale            98.0

# %%
high_income_areas = df[df['PER CAPITA INCOME '] > 60000]
display(high_income_areas[['COMMUNITY AREA NAME', 'PER CAPITA INCOME ']])
# Out:
#    COMMUNITY AREA NAME  PER CAPITA INCOME
# 5            Lake View               60058
# 6         Lincoln Park               71551
# 7      Near North Side               88669
# 31                Loop               65526
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['PER CAPITA INCOME '].plot(kind='hist', bins=20, title='PER CAPITA INCOME ')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df['PER CAPITA INCOME '], df['HARDSHIP INDEX'])
plt.xlabel('Per Capita Income')
plt.ylabel('Hardship Index')
plt.title('Per Capita Income vs. Hardship Index in Chicago Community Areas')
plt.grid(True)
plt.show()
